# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style("darkgrid")

# %%
data = pd.read_csv('../../data/processed/trial4.csv')

# %%
plt.figure(figsize=(8, 4))
plt.title("LogKp Distribution")
data.logkpl.hist();

# %%
corr_matrix = data.corr()

#the matrix is symmetric so we need to extract upper triangle matrix without diagonal (k = 1)

sol = (corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(bool))
                  .stack()
                  .sort_values(ascending=False))

# %%
filtered_sol = sol[sol ==1]
filtered_sol
# Out:
# khs.sLi     khs.sssNH    1.0
# khs.ssNH2   khs.sI       1.0
# khs.ssssBe  khs.sPbH3    1.0
# khs.tsC     khs.tN       1.0
# C1SP1       khs.tsC      1.0
#             khs.tN       1.0
# dtype: float64

# %%
lst = []
c = 0
for index, value in sol.items():

  if index[0] == "logkpl" or index[1] == "logkpl":

    plt.scatter(x=index[0], y=index[1], data=data)
    plt.show()
    
    lst.append(index[0])
    lst.append(index[1])

  # if c == 10:
  #   break

  c+=1
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 8
#       5 if index[0] == "logkpl" or index[1] == "logkpl":
#       7   plt.scatter(x=index[0], y=index[1], data=data)
# ----> 8   plt.show()
#      10   lst.append(index[0])
#      11   lst.append(index[1])
#
# File c:\Users\ahmed\miniconda3\envs\ds\lib\site-packages\matplotlib\pyplot.py:421, in show(*args, **kwargs)
#     377 """
#     378 Display all open figures.
#     379
#    (...)
#     418 explicitly there.
#     419 """
#     420 _warn_if_gui_out_of_main_thread()
# --> 421 return _get_backend_mod().show(*args, **kwargs)
#
# File c:\Users\ahmed\miniconda3\envs\ds\lib\site-packages\matplotlib_inline\backend_inline.py:90, in show(close, block)
#      88 try:
#      89     for figure_manager in Gcf.get_all_fig_managers():
# ---> 90         display(
#      91             figure_manager.canvas.figure,
#      92             metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      93         )
#      94 finally:
#      95     show._to_draw = []
#
# File c:\Users\ahmed\miniconda3\envs\ds\lib\site-packages\IPython\core\display_functions.py:298, in display(include, exclude, metadata, transient, display_id, raw, clear, *objs, **kwargs)
#     296     publish_display_data(data=obj, metadata=metadata, **kwargs)
#     297 else:
# --> 298     format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     299     if not format_dict:
#     300         # nothing to display (e.g. _ipython_display_ took over)
#     301         continue
#
# File c:\Users\ahmed\miniconda3\envs\ds\lib\site-packages\IPython\core\formatters.py:177, in DisplayFormatter.format(self, obj, include, exclude)
#     175 md = None
#     176 try:
# --> 177     data = formatter(obj)
#     178 except:
#     179     # FIXME: log the exception
#     180     raise
#
# File c:\Users\ahmed\miniconda3\envs\ds\lib\site-packages\decorator.py:232, in decorate.<locals>.fun(*args, **kw)
#     230 if not kwsyntax:
#     231     args, kw = fix(args, kw, sig)
# --> 232 return caller(func, *(extras + args), **kw)
#
# File c:\Users\ahmed\miniconda3\envs\ds\lib\site-packages\IPython\core\formatters.py:221, in catch_format_error(method, self, *args, **kwargs)
#     219 """show traceback on failed format call"""
#     220 try:
# --> 221     r = method(self, *args, **kwargs)
#     222 except NotImplementedError:
#     223     # don't warn on NotImplementedErrors
#     224     return self._check_return(None, args[0])
#
# File c:\Users\ahmed\miniconda3\envs\ds\lib\site-packages\IPython\core\formatters.py:338, in BaseFormatter.__call__(self, obj)
#     336     pass
#     337 else:
# --> 338     return printer(obj)
#     339 # Finally look for special method names
#     340 method = get_real_method(obj, self.print_method)
#
# File c:\Users\ahmed\miniconda3\envs\ds\lib\site-packages\IPython\core\pylabtools.py:152, in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     149     from matplotlib.backend_bases import FigureCanvasBase
#     150     FigureCanvasBase(fig)
# --> 152 fig.canvas.print_figure(bytes_io, **kw)
#     153 data = bytes_io.getvalue()
#     154 if fmt == 'svg':
#
# File c:\Users\ahmed\miniconda3\envs\ds\lib\site-packages\matplotlib\backend_bases.py:2318, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2316 if bbox_inches:
#    2317     if bbox_inches == "tight":
# -> 2318         bbox_inches = self.figure.get_tightbbox(
#    2319             renderer, bbox_extra_artists=bbox_extra_artists)
#    2320         if pad_inches is None:
#    2321             pad_inches = rcParams['savefig.pad_inches']
#
# File c:\Users\ahmed\miniconda3\envs\ds\lib\site-packages\matplotlib\figure.py:1734, in FigureBase.get_tightbbox(self, renderer, bbox_extra_artists)
#    1731     artists = bbox_extra_artists
#    1733 for a in artists:
# -> 1734     bbox = a.get_tightbbox(renderer)
#    1735     if bbox is not None:
#    1736         bb.append(bbox)
#
# File c:\Users\ahmed\miniconda3\envs\ds\lib\site-packages\matplotlib\axes\_base.py:4431, in _AxesBase.get_tightbbox(self, renderer, call_axes_locator, bbox_extra_artists, for_layout_only)
#    4429         if ba:
#    4430             bb.append(ba)
# -> 4431 self._update_title_position(renderer)
#    4432 axbbox = self.get_window_extent(renderer)
#    4433 bb.append(axbbox)
#
# File c:\Users\ahmed\miniconda3\envs\ds\lib\site-packages\matplotlib\axes\_base.py:3006, in _AxesBase._update_title_position(self, renderer)
#    3003 bb = None
#    3004 if (ax.xaxis.get_ticks_position() in ['top', 'unknown']
#    3005         or ax.xaxis.get_label_position() == 'top'):
# -> 3006     bb = ax.xaxis.get_tightbbox(renderer)
#    3007 if bb is None:
#    3008     if 'outline' in ax.spines:
#    3009         # Special case for colorbars:
#
# File c:\Users\ahmed\miniconda3\envs\ds\lib\site-packages\matplotlib\axis.py:1256, in Axis.get_tightbbox(self, renderer, for_layout_only)
#    1253 self._update_label_position(renderer)
#    1255 # go back to just this axis's tick labels
# -> 1256 tlb1, tlb2 = self._get_ticklabel_bboxes(ticks_to_draw, renderer)
#    1258 self._update_offset_text_position(tlb1, tlb2)
#    1259 self.offsetText.set_text(self.major.formatter.get_offset())
#
# File c:\Users\ahmed\miniconda3\envs\ds\lib\site-packages\matplotlib\axis.py:1232, in Axis._get_ticklabel_bboxes(self, ticks, renderer)
#    1230 if renderer is None:
#    1231     renderer = self.figure._get_renderer()
# -> 1232 return ([tick.label1.get_window_extent(renderer)
#    1233          for tick in ticks if tick.label1.get_visible()],
#    1234         [tick.label2.get_window_extent(renderer)
#    1235          for tick in ticks if tick.label2.get_visible()])
#
# File c:\Users\ahmed\miniconda3\envs\ds\lib\site-packages\matplotlib\axis.py:1232, in <listcomp>(.0)
#    1230 if renderer is None:
#    1231     renderer = self.figure._get_renderer()
# -> 1232 return ([tick.label1.get_window_extent(renderer)
#    1233          for tick in ticks if tick.label1.get_visible()],
#    1234         [tick.label2.get_window_extent(renderer)
#    1235          for tick in ticks if tick.label2.get_visible()])
#
# File c:\Users\ahmed\miniconda3\envs\ds\lib\site-packages\matplotlib\text.py:917, in Text.get_window_extent(self, renderer, dpi)
#     915 bbox, info, descent = self._get_layout(self._renderer)
#     916 x, y = self.get_unitless_position()
# --> 917 x, y = self.get_transform().transform((x, y))
#     918 bbox = bbox.translated(x, y)
#     919 return bbox
#
# File c:\Users\ahmed\miniconda3\envs\ds\lib\site-packages\matplotlib\transforms.py:1490, in Transform.transform(self, values)
#    1487 values = values.reshape((-1, self.input_dims))
#    1489 # Transform the values
# -> 1490 res = self.transform_affine(self.transform_non_affine(values))
#    1492 # Convert the result back to the shape of the input values.
#    1493 if ndim == 0:
#
# File c:\Users\ahmed\miniconda3\envs\ds\lib\site-packages\matplotlib\transforms.py:2420, in CompositeGenericTransform.transform_affine(self, points)
#    2418 def transform_affine(self, points):
#    2419     # docstring inherited
# -> 2420     return self.get_affine().transform(points)
#
# File c:\Users\ahmed\miniconda3\envs\ds\lib\site-packages\matplotlib\transforms.py:2446, in CompositeGenericTransform.get_affine(self)
#    2444     return self._b.get_affine()
#    2445 else:
# -> 2446     return Affine2D(np.dot(self._b.get_affine().get_matrix(),
#    2447                            self._a.get_affine().get_matrix()))
#
# File <__array_function__ internals>:180, in dot(*args, **kwargs)
#
# KeyboardInterrupt:

# %%
sol[sol > 0.7]
# Out:
# khs.ssssPb  nRings4       1.000000
# khs.ssssB   nRings4       1.000000
# khs.ssNH2   khs.ssssPb    1.000000
# khs.sI      nRings4       1.000000
# khs.ssNH2   nRings4       1.000000
#                             ...
# BCUTw-1l    khs.ssssBe    0.701847
# SC-3        MDEC-12       0.701751
# ATSc1       nHBDon        0.700598
# ECCEN       MDEC-13       0.700357
# VCH-3       MDEN-11       0.700343
# Length: 2894, dtype: float64

# %%
c
# Out:
# 307

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(data[lst].corr())
# Out:
# <AxesSubplot: >
